# %%
students_list= ["Sabrina","Samiha","Tonoy","Maiyam"]
students_list.remove("Sabrina")
print(students_list)
# Out:
# ['Samiha', 'Tonoy', 'Maiyam']

# %%
students_list.append("Sabrina")
print(students_list)
# Out:
# ['Samiha', 'Tonoy', 'Maiyam', 'Sabrina']

# %%
print(type(students_list))
print(len(students_list))
# Out:
# <class 'list'>
# 4

# %%
print("First entry",students_list[0])
# Out:
# First entry Sabrina

# %%
menu=["stewed meat with onions","bean soup","risotto with trout and shrimp","fish soup with cream and onion","gryo"]
print(menu)
menu.remove("bean soup")
print(menu)
menu.append("bean soup")
print(menu)
# Out:
# ['stewed meat with onions', 'bean soup', 'risotto with trout and shrimp', 'fish soup with cream and onion', 'gryo']
# ['stewed meat with onions', 'risotto with trout and shrimp', 'fish soup with cream and onion', 'gryo']
# ['stewed meat with onions', 'risotto with trout and shrimp', 'fish soup with cream and onion', 'gryo', 'bean soup']

# %%
num_customers=[137,147,135,128,170,174,165,146,126,159,141,148,132,147,168,153,170,161,148,152,141,151,131,149,164,163,143,143,166,171]
avg_first_seven= sum(num_customers[:7])/7
print(avg_first_seven)
# Out:
# 150.85714285714286

# %%
avg_last_seven= sum(num_customers[-7:])/7
print(avg_last_seven)
# Out:
# 157.0

# %%
print("maximum",max(num_customers))
print("minimum",min(num_customers))
# Out:
# maximum 174
# minimum 126

# %%
students="Sabrina,Samiha,Tonoy,Maiyam"
my_list=students.split(",")
print(my_list)
print(type(my_list))
print(len(my_list))
# Out:
# ['Sabrina', 'Samiha', 'Tonoy', 'Maiyam']
# <class 'list'>
# 4
