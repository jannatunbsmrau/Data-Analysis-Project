# %%
def get_cost(sqft_walls,sqft_ceiling,sqft_per_gallon,cost_per_gallon):
    total_sqft= sqft_walls+sqft_ceiling
    total_cost= (1/sqft_per_gallon)*cost_per_gallon
    paint_cost=total_sqft*total_cost
    return paint_cost

# %%
pay= get_cost(432,144,400,15)
print(pay)
# Out:
# 21.599999999999998
